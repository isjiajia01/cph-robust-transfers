# %% [markdown]
# # Week2 Robustness Experiments (Auto-Generated)
#
# This notebook is generated from `src.robustness.update_week2_notebook`.
#
# Data source directory:
# - `../data/robustness/20260302_high`

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

base = Path("../data/robustness/20260302_high")
summary = pd.read_csv(base / "robustness_summary.csv")
critical = pd.read_csv(base / "critical_nodes_top10.csv")

lcc_curve = Path("../docs/figures/week2_random_vs_targeted.png")
extra_curve = Path("../docs/figures/week2_extra_metrics.png")

# %% [markdown]
# ## Random vs Targeted (LCC Curve)

# %%
display(Image(filename=str(lcc_curve)))

# %% [markdown]
# ## Extra Metrics (Reachable OD ratio / Avg shortest path)

# %%
display(Image(filename=str(extra_curve)))

# %% [markdown]
# ## Robustness Summary

# %%
summary.sort_values(['k_pct', 'strategy']).reset_index(drop=True)

# %% [markdown]
# ## Top-10 Critical Nodes

# %%
critical
