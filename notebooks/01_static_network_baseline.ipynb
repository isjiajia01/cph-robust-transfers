# %% [markdown]
# # Week1 Static Network Baseline
#
# Data snapshot: `data/gtfs/parsed/20260302` and `data/graph/20260302`.

# %%
from pathlib import Path
import pandas as pd

summary = Path('../docs/week1_summary.md').read_text(encoding='utf-8')
print(summary)

# %%
from IPython.display import Image, display
display(Image(filename='../docs/figures/week1_top_hubs.png'))
display(Image(filename='../docs/figures/week1_component_sizes.png'))

# %%
metrics = pd.read_csv('../data/graph/20260302/metrics.csv')
metrics.sort_values(['in_degree','out_degree'], ascending=False).head(20)
