# %% [markdown]
# # Week3 Realtime Delay Profile
#
# Inputs: latest Cloud Run collector run + BigQuery quantile export.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

bq = pd.read_csv('../data/analysis/delay_quantiles_bq.csv')
bq.sort_values('p95_delay_sec', ascending=False).head(20)

# %%
display(Image(filename='../docs/figures/week3_delay_quantiles_by_line.png'))
display(Image(filename='../docs/figures/week3_delay_p95_by_hour.png'))

# %%
print(Path('../docs/week3_summary.md').read_text(encoding='utf-8'))
